# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from io import StringIO

# %%
csv_data = '''A,B,C,D,E
            5.0,2.0,3.0,,6
            1.0,6.0,,8.0,5
            0.0,11.0,12.0,4.0,5
            3.0,,3.0,5.0,
            5.0,1.0,4.0,2.0,4
           '''

# %%
df = pd.read_csv(StringIO(csv_data))

# %%
df
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   NaN   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.dropna()
# Out:
#      A     B     C    D    E
# 2  0.0  11.0  12.0  4.0  5.0
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.dropna(how = 'all')
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   NaN   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.dropna(subset=['C'])
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   NaN   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.fillna(0)
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  0.0  6.0
# 1  1.0   6.0   0.0  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   0.0   3.0  5.0  0.0
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df['B'] = df['B'].fillna(df['B'].mean())
df
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   5.0   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
#df['C'] = df['C'].fillna(df['C'].mode())
df['C'].fillna(df['C'].mode())
# Out:
# 0     3.0
# 1     NaN
# 2    12.0
# 3     3.0
# 4     4.0
# Name: C, dtype: float64

# %%
df2 = pd.DataFrame(
    [
        ['green', 'M', 10.1, 1],
        ['red', 'L', 13.5, 2],
        ['blue', 'XL', 15.3, 1]
    ]
)
df2.columns = ['color', 'size', 'price', 'classlabel']
df2
# Out:
#    color size  price  classlabel
# 0  green    M   10.1           1
# 1    red    L   13.5           2
# 2   blue   XL   15.3           1

# %%
size_mapping = {
    'XL':3,
    'L':2,
    'M':1
}

df2['size'] = df2['size'].map(size_mapping)
df2
# Out:
#    color  size  price  classlabel
# 0  green     1   10.1           1
# 1    red     2   13.5           2
# 2   blue     3   15.3           1

# %%
pd.get_dummies(df2['color'])
# Out:
#    blue  green  red
# 0     0      1    0
# 1     0      0    1
# 2     1      0    0

# %%
onehot_encoding = pd.get_dummies(df2['color'], prefix = 'color')
onehot_encoding
# Out:
#    color_blue  color_green  color_red
# 0           0            1          0
# 1           0            0          1
# 2           1            0          0

# %%
df2.drop('color', 1)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#    size  price  classlabel
# 0     1   10.1           1
# 1     2   13.5           2
# 2     3   15.3           1

# %%
df2 = df2.drop('color', 1)
df2
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2863cec20b72> in <module>
# ----> 1 df2 = df2.drop('color', 1)
#       2 df2
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4906             level=level,
#    4907             inplace=inplace,
# -> 4908             errors=errors,
#    4909         )
#    4910
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4145         for axis, labels in axes.items():
#    4146             if labels is not None:
# -> 4147                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4148
#    4149         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4180                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4181             else:
# -> 4182                 new_axis = axis.drop(labels, errors=errors)
#    4183             result = self.reindex(**{axis_name: new_axis})
#    4184
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6016         if mask.any():
#    6017             if errors != "ignore":
# -> 6018                 raise KeyError(f"{labels[mask]} not found in axis")
#    6019             indexer = indexer[~mask]
#    6020         return self.delete(indexer)
#
# KeyError: "['color'] not found in axis"

# %%
pd.concat([onehot_encoding, df2], axis = 1)
# Out:
#    color_blue  color_green  color_red  size  price  classlabel
# 0           0            1          0     1   10.1           1
# 1           0            0          1     2   13.5           2
# 2           1            0          0     3   15.3           1

# %%
# Out:
#    size  price  classlabel
# 0     1   10.1           1
# 1     2   13.5           2
# 2     3   15.3           1
